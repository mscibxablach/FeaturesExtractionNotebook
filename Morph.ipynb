# %% [markdown]
# ## Jupyter declarations

# %%
# %matplotlib inline

# %% [markdown]
# ## Imports

# %%
import cv2
import numpy as np
import math
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %% [markdown]
# ## Show image

# %%
def show_image(title, image):
    plt.imshow(image)
    plt.title(title)
    plt.show()

# %% [markdown]
# ## Load image

# %%
def read_image(filename):
    return cv2.imread(filename)

filename = 'Photos/43.jpg'
image = read_image(filename)

show_image('image', image)

# %% [markdown]
# ## Blur

# %%
def blur(image):
    image = image.copy()
    return cv2.blur(image, (5,5))

blur_result = blur(image)
show_image('blur', blur_result)

# %% [markdown]
# ## Threshold

# %%
def threshold(image):
    image = image.copy()
    return cv2.threshold(image, 70, 255, cv2.THRESH_BINARY)

blur1 = blur(image)
_, thresh = threshold(image)
x = threshold(blur1)
show_image('image', image)
show_image('threshold', thresh)
show_image('blured threshold', x)
print(blured_threshold)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-386f5591ae96> in <module>
#       8 show_image('image', image)
#       9 show_image('threshold', thresh)
# ---> 10 show_image('blured threshold', x)
#      11 print(blured_threshold)
#
# <ipython-input-3-7bd6185b1113> in show_image(title, image)
#       1 def show_image(title, image):
# ----> 2     plt.imshow(image)
#       3     plt.title(title)
#       4     plt.show()
#
# ~/anaconda3/envs/opencv-notebook/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2675         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2676         resample=resample, url=url, **({"data": data} if data is not
# -> 2677         None else {}), **kwargs)
# ...

# %% [markdown]
# ## Erosion

# %%
def erosion(image):
    image = image.copy()
    kernel = np.ones((5,5), np.uint8)
    return cv2.erode(image, kernel, iterations=1)

_, thresh = threshold(image)
thresh_erosion_result = erosion(thresh)
erosion_result = erosion(image)
show_image('image', image)
show_image('erosion', erosion_result)
show_image('thresh erosion', thresh_erosion_result)

# %% [markdown]
# ## Dilation

# %%
def dilate(image):
    image = image.copy()
    kernel = np.ones((3,3), np.uint8)
    return cv2.dilate(image, kernel, iterations=1)

_, thresh = threshold(image)
dilate_thresh = dilate(thresh)
dilate_result = dilate(image)

show_image('image', image)
show_image('dilate result', dilate_result)
show_image('thresh dilate', dilate_thresh)

# %% [markdown]
# ## Opening

# %%
def opening(image):
    image = image.copy()
    kernel = np.ones((5,5), np.uint8)
    return cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

_, thresh = threshold(image)
opening_thresh = opening(thresh)
opening_result = opening(image)

show_image('image', image)
show_image('opening thresh', opening_thresh)
show_image('opening result', opening_result)

# %% [markdown]
# ## Closing

# %%
def closing(image):
    image = image.copy()
    kernel = np.ones((5,5), np.uint8)
    return cv2.morphologyEx(image, cv2.MORPH_CLOSE, kernel)

_, thresh = threshold(image)
closing_thresh = closing(thresh)
closing_result = closing(image)

show_image('image', image)
show_image('closing result', closing_result)
show_image('closing thresh', closing_thresh)

# %% [markdown]
# ## Thresh-opening-closing

# %%
_, thresh = threshold(image)
result_opening = opening(thresh)
result_closing = closing(result_opening)
show_image('image', image)
show_image('result', result_closing)

# %% [markdown]
# ## Opening-closing

# %%
image1 = read_image(filename)
blur_x = cv2.blur(image1, (5,5))
_, thresh1 = threshold(blur_x)
opening1 = opening(thresh1)
closing1 = closing(opening1)

show_image('image', image1)
show_image('blur', blur_x)
show_image('thresh', thresh1)
show_image('opening', opening1)
show_image('closing', closing1)
